# %%
import pandas as pd

# %%
company_name=pd.read_csv('Company.csv')

# %%
company_name
# Out:
#   ticker_symbol company_name
# 0          AAPL        apple
# 1          GOOG   Google Inc
# 2         GOOGL   Google Inc
# 3          AMZN   Amazon.com
# 4          TSLA    Tesla Inc
# 5          MSFT    Microsoft

# %%
tweets_data=pd.read_csv('Tweet.csv')

# %%
tweets_data
# Out:
#                     tweet_id           writer   post_date  \
# 0         550441509175443456  VisualStockRSRC  1420070457
# 1         550441672312512512      KeralaGuy77  1420070496
# 2         550441732014223360      DozenStocks  1420070510
# 3         550442977802207232     ShowDreamCar  1420070807
# 4         550443807834402816     i_Know_First  1420071005
# ...                      ...              ...         ...
# 3717959  1212159765914079234        TEEELAZER  1577836383
# 3717960  1212159838882533376    ShortingIsFun  1577836401
# 3717961  1212160015332728833      Commuternyc  1577836443
# 3717962  1212160410692046849      MoriaCrypto  1577836537
# 3717963  1212160477159206912         treabase  1577836553
#
#                                                       body  comment_num  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1        Insanity of today weirdo massive selling. $aap...            0
# ...

# %%
company_tweet_data=pd.read_csv('Company_Tweet.csv')

# %%
company_tweet_data
# Out:
#                     tweet_id ticker_symbol
# 0         550803612197457920          AAPL
# 1         550803610825928706          AAPL
# 2         550803225113157632          AAPL
# 3         550802957370159104          AAPL
# 4         550802855129382912          AAPL
# ...                      ...           ...
# 4336440  1212158772015034369          TSLA
# 4336441  1212159099632267268          TSLA
# 4336442  1212159184931717120          TSLA
# 4336443  1212159838882533376          TSLA
# 4336444  1212160015332728833          TSLA
#
# [4336445 rows x 2 columns]

# %%
data=pd.merge(company_tweet_data, tweets_data)

# %%
data
# Out:
#                     tweet_id ticker_symbol          writer   post_date  \
# 0         550803612197457920          AAPL      SentiQuant  1420156789
# 1         550803612197457920          AMZN      SentiQuant  1420156789
# 2         550803610825928706          AAPL      SentiQuant  1420156788
# 3         550803610825928706         GOOGL      SentiQuant  1420156788
# 4         550803610825928706          AMZN      SentiQuant  1420156788
# ...                      ...           ...             ...         ...
# 4336440  1212158772015034369          TSLA       StockJoke  1577836146
# 4336441  1212159099632267268          TSLA       sweetog76  1577836224
# 4336442  1212159184931717120          TSLA  MelaynaLokosky  1577836245
# 4336443  1212159838882533376          TSLA   ShortingIsFun  1577836401
# 4336444  1212160015332728833          TSLA     Commuternyc  1577836443
#
#                                                       body  comment_num  \
# ...

# %%
dataset=pd.merge(data,company_name)

# %%
dataset
# Out:
#                     tweet_id ticker_symbol          writer   post_date  \
# 0         550803612197457920          AAPL      SentiQuant  1420156789
# 1         550803610825928706          AAPL      SentiQuant  1420156788
# 2         550803225113157632          AAPL     MacHashNews  1420156696
# 3         550802957370159104          AAPL   WaltLightShed  1420156633
# 4         550802855129382912          AAPL    2waystrading  1420156608
# ...                      ...           ...             ...         ...
# 4336440  1212122611192336394          MSFT       LadeBackk  1577827525
# 4336441  1212131912585826305          MSFT      robintrack  1577829742
# 4336442  1212145214736875520          MSFT  MarketCurrents  1577832914
# 4336443  1212146425607413761          MSFT   SentimEntropy  1577833203
# 4336444  1212154474422099970          MSFT   TheUnicornBay  1577835122
#
#                                                       body  comment_num  \
# ...

# %%
dataset.to_csv('allcompany.csv')

# %%
df1 = dataset[dataset['company_name'] == 'apple']

# %%
df2 = dataset[dataset['company_name'] == 'Microsoft']

# %%
df3 = dataset[dataset['company_name'] == 'Amazon.com']

# %%
df4 = dataset[dataset['company_name'] == 'Tesla Inc']

# %%
df5 = dataset[dataset['company_name'] == 'Google Inc']

# %%
# Out:
#                     tweet_id ticker_symbol           writer   post_date  \
# 2143728   550803610825928706         GOOGL       SentiQuant  1420156788
# 2143729   550795088821886976         GOOGL     MarkDePompeo  1420154757
# 2143730   550759232455585792         GOOGL    CloudChipotle  1420146208
# 2143731   550739393812508673         GOOGL  laurenholmesNYC  1420141478
# 2143732   550726640347922433         GOOGL       caroltheva  1420138437
# ...                      ...           ...              ...         ...
# 3960729  1212145324296458241          GOOG   tradeoilstocks  1577832940
# 3960730  1212145509579837440          GOOG        econalert  1577832984
# 3960731  1212146656335949824          GOOG  SVPR_Sweetheart  1577833258
# 3960732  1212154645981941760          GOOG  TopStockAlerts1  1577835163
# 3960733  1212159132758728704          GOOG          wilwen2  1577836232
#
#                                                       body  comment_num  \
# ...

# %%
df1.to_csv('apple.csv')

# %%
df2.to_csv('Microsoft.csv')

# %%
df3.to_csv('Amazon.csv')

# %%
df4.to_csv('Tesla.csv')

# %%
df5.to_csv('google.csv')
